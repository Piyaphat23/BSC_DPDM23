# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyaphat23/BSC_DPDM23/blob/main/Frequent_Patterns_(Association_Rules).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/BSC_DPDM23'
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/BSC_DPDM23/reduced_marketbasket.csv'),encoding='latin-1')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# #แปล Data ให้อยู่ในรูปแบบ Transaction data ด้วย groupby.apply(list)

# %%
data.groupby('InvoiceNo')['StockCode'].apply(list)
# Out:
# InvoiceNo
# 536365     [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# 536366                                        [22633, 22632]
# 536367     [84879, 22745, 22748, 22749, 22310, 84969, 226...
# 536368                          [22960, 22913, 22912, 22914]
# 536369                                               [21756]
#                                  ...
# C581484                                              [23843]
# C581490                                       [22178, 23144]
# C581499                                                  [M]
# C581568                                              [21258]
# C581569                                       [84978, 20979]
# Name: StockCode, Length: 25900, dtype: object

# %%
transactions = data.groupby('InvoiceNo')['StockCode'].apply(list)

# %% [markdown]
# *  ดูประเทศ

# %%
set(data["Country"])
# Out:
# {'Australia',
#  'Austria',
#  'Bahrain',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Channel Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'EIRE',
#  'European Community',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Lebanon',
#  'Lithuania',
#  'Malta',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'RSA',
#  'Saudi Arabia',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'USA',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Unspecified'}

# %% [markdown]
# ## Association Rules

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %%
from apyori import apriori

# %%
 frequentItemsets = list(apriori(transactions,min_support = 0.065))
 frequentItemsets
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
len(frequentItemsets)
# Out:
# 4

# %%
frequentItemsets[0][0]
# Out:
# frozenset({'22423'})

# %%
dir(frequentItemsets[0][0])
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'copy',
#  'difference',
#  'intersection',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'symmetric_difference',
#  'union']

# %%
frequentItemsets[0][0].__len__()
# Out:
# 1

# %%
min_sup = 0.03

frequentItemsets = list(apriori(transactions,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'85099B', '22386'}), support=0.03216216216216216, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B', '22386'}), confidence=0.03216216216216216, lift=1.0), OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335), OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])
# yes
# RelationRecord(items=frozenset({'22699', '22697'}), support=0.03027027027027027, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22699', '22697'}), confidence=0.03027027027027027, lift=1.0), OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947), OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %% [markdown]
# RelationRecord(items=frozenset({'22386', '85099B'}),
#
# support=0.03216216216216216,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03216216216216216, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335),
#
# OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])

# %%
set(data[(data['StockCode']=='22386') | (data['StockCode']=='85099B') | (data['StockCode']=='22699') | (data['StockCode']=='22697') ]['Description'])
# Out:
# {'GREEN REGENCY TEACUP AND SAUCER',
#  'JUMBO BAG PINK POLKADOT',
#  'JUMBO BAG RED RETROSPOT',
#  'ROSES REGENCY TEACUP AND SAUCER '}

# %% [markdown]
# #Quiz 2236 และ 85099B คือสินค้าอะไร

# %% [markdown]
# RelationRecord(items=frozenset({'22699', '22697'}), support=0.03027027027027027,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22699', '22697'}), confidence=0.03027027027027027, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947),
#
# OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %%
set(data[(data['StockCode']=='22699') | (data['StockCode']=='22697')]['InvoiceNo'])
# Out:
# {'540646',
#  '543106',
#  '548987',
#  '552664',
#  '574334',
#  '574852',
#  '579012',
#  'C560588',
#  '560246',
#  '553462',
#  '549192',
#  '566600',
#  '565286',
#  '580727',
#  '552816',
#  '568199',
#  '574328',
#  '547250',
#  '561631',
#  '541960',
#  '557859',
#  'C544665',
#  '550186',
#  '555524',
#  '552867',
#  'C543633',
#  '544186',
#  '565917',
#  '545701',
#  '537335',
#  '536980',
#  '550638',
#  '544677',
#  '568567',
#  '556416',
#  '541421',
#  '555158',
#  '571508',
#  '551088',
#  '562113',
#  '560504',
#  '538177',
#  '566597',
#  '544888',
#  '570258',
#  '564541',
#  '545719',
#  '566221',
#  '555722',
#  '547248',
#  '537434',
#  '543097',
#  '558565',
#  '574298',
#  '579777',
#  '563442',
#  '544339',
#  '551960',
#  'C538059',
#  '542862',
#  '571546',
#  '579267',
#  '575607',
#  '568411',
#  '565155',
#  '545526',
#  '536523',
#  '537313',
#  '578347',
#  '550519',
#  '580501',
#  '553768',
#  '553709',
#  '572854',
#  '547841',
#  '570688',
#  '545063',
#  'C559667',
#  '575221',
#  '549525',
#  '572897',
#  '580612',
#  'C542912',
#  '558073',
#  '548260',
#  '541506',
#  '551860',
#  '561926',
#  '570701',
#  '551550',
#  '562934',
#  '566537',
#  '571241',
#  '554935',
#  '563931',
#  '574707',
#  '544301',
#  '555594',
#  '548516',
#  '554030',
#  '551850',
#  'C578144',
#  '573892',
#  '572758',
#  '543277',
#  '544434',
#  '557605',
#  '540005',
#  '550458',
#  '566477',
#  '574950',
#  '579938',
#  '552956',
#  '559134',
#  '561089',
#  '549222',
#  '543530',
#  '554026',
#  '549951',
#  '570465',
#  '545945',
#  '578993',
#  '566988',
#  '561633',
#  '555522',
#  '581238',
#  '545216',
#  '538153',
#  '554124',
#  '540981',
#  '539708',
#  '556434',
#  'C539467',
#  '570187',
#  '549425',
#  '554039',
#  '554704',
#  '537396',
#  '553607',
#  '577531',
#  '549360',
#  '567184',
#  '576381',
#  '547949',
#  '551340',
#  '557735',
#  '542881',
#  'C562921',
#  '545340',
#  '549261',
#  'C545525',
#  '561070',
#  '541220',
#  '554098',
#  '542590',
#  '544684',
#  '581439',
#  '540465',
#  'C552016',
#  '536530',
#  '579445',
#  '548974',
#  '555695',
#  '569246',
#  '562202',
#  '546683',
#  '550986',
#  '554158',
#  '544767',
#  '550307',
#  '558103',
#  '563505',
#  '560580',
#  '563384',
#  '546892',
#  'C551465',
#  '547498',
#  '569545',
#  '544837',
#  '555743',
#  '542622',
#  '542087',
#  '548212',
#  '558681',
#  '544657',
#  '550470',
#  '537470',
#  '540915',
#  '544421',
#  '544569',
#  '565150',
#  '548663',
#  'C558255',
#  '537042',
#  '541695',
#  '560780',
#  '576246',
#  'C537853',
#  '566170',
#  '537179',
#  '547399',
#  '569202',
#  '548514',
#  '539442',
#  '546896',
#  '561651',
#  '549997',
#  '544338',
#  'C564854',
#  '562377',
#  '547846',
#  '564301',
#  'C541822',
#  '558540',
#  '561645',
#  '544394',
#  '563613',
#  '551062',
#  '546314',
#  '557621',
#  '543565',
#  '537022',
#  '553202',
#  '548409',
#  '579885',
#  '568310',
#  '555488',
#  '545474',
#  '562353',
#  '566193',
#  '561394',
#  '564172',
#  '562843',
#  '568955',
#  '577400',
#  '563193',
#  '538851',
#  '552734',
#  '551173',
#  '565424',
#  '543370',
#  '552270',
#  '554921',
#  '570270',
#  '543251',
#  '551944',
#  '552308',
#  '567336',
#  '573585',
#  '538862',
#  '545812',
#  '547042',
#  '564091',
#  '544940',
#  '545215',
#  '573511',
#  '563076',
#  '543485',
#  '555925',
#  '554557',
#  '578344',
#  'C539071',
#  '580066',
#  '537237',
#  '548714',
#  '553146',
#  '543467',
#  '548373',
#  '567670',
#  '560772',
#  '554337',
#  '540662',
#  'C546865',
#  '579196',
#  '570374',
#  '559493',
#  'C558312',
#  '564191',
#  '567528',
#  '550968',
#  '539451',
#  '556953',
#  '546760',
#  '564754',
#  '558702',
#  '538370',
#  '552715',
#  '546927',
#  '566602',
#  '555499',
#  '557034',
#  '541110',
#  '570713',
#  '558035',
#  '554036',
#  '545320',
#  '552449',
#  '558683',
#  '581492',
#  '572553',
#  '543201',
#  '575930',
#  '564857',
#  '566985',
#  '578817',
#  '577298',
#  '579503',
#  '553869',
#  '562770',
#  '577078',
#  '552149',
#  '541132',
#  '547385',
#  '565724',
#  '550503',
#  '573580',
#  '567663',
#  '547580',
#  '571034',
#  '580098',
#  '581023',
#  '571560',
#  '564758',
#  'C537834',
#  '536544',
#  '579539',
#  '576329',
#  '543487',
#  'C549315',
#  '556243',
#  '556783',
#  '576837',
#  '554714',
#  '548163',
#  '555574',
#  '548733',
#  '545464',
#  '571377',
#  '541783',
#  '580669',
#  '541870',
#  '565234',
#  '577691',
#  '564065',
#  '563614',
#  '580667',
#  '544920',
#  '580774',
#  '539635',
#  '581217',
#  '539217',
#  '543036',
#  '580610',
#  '544660',
#  '549435',
#  '553891',
#  '572066',
#  '558774',
#  '566720',
#  '566581',
#  '577355',
#  '550251',
#  '543629',
#  '562427',
#  '577029',
#  '566603',
#  '554798',
#  '580729',
#  '546891',
#  '553542',
#  '574368',
#  '580673',
#  '567905',
#  '575185',
#  '543754',
#  '568654',
#  '548003',
#  '553541',
#  '580665',
#  '543546',
#  '555275',
#  '557145',
#  '560634',
#  '545020',
#  '549295',
#  '572035',
#  '549999',
#  '547964',
#  '573070',
#  '539739',
#  '553210',
#  '575176',
#  '558120',
#  '565120',
#  '577071',
#  '558068',
#  '552196',
#  '550183',
#  '557259',
#  '564820',
#  '550958',
#  '566446',
#  '579102',
#  '556095',
#  '563166',
#  '559510',
#  '544681',
#  '559827',
#  '554483',
#  '547788',
#  '569493',
#  '546992',
#  '577498',
#  '568193',
#  '550987',
#  '550265',
#  '539468',
#  '546136',
#  '538148',
#  '559295',
#  '540907',
#  '573338',
#  '561051',
#  '553661',
#  '542632',
#  '547387',
#  '537176',
#  '536876',
#  '546980',
#  '575063',
#  '548893',
#  'C556880',
#  '558443',
#  '578354',
#  '542779',
#  '578065',
#  '552678',
#  '548210',
#  '544893',
#  '572549',
#  '552975',
#  '562273',
#  '559112',
#  '573320',
#  '575846',
#  '565847',
#  '580173',
#  '552259',
#  '572751',
#  '575931',
#  '544812',
#  '568333',
#  '569888',
#  '561209',
#  '553162',
#  '554514',
#  '548718',
#  '546888',
#  '537240',
#  '563169',
#  '544314',
#  '551014',
#  '549124',
#  '554054',
#  '571305',
#  '572229',
#  '567671',
#  '559800',
#  '545032',
#  '553385',
#  '546915',
#  '559923',
#  '568676',
#  '567368',
#  '578936',
#  '545429',
#  '566290',
#  '576690',
#  '552825',
#  '565781',
#  '555278',
#  'C561232',
#  '539736',
#  '551414',
#  '556259',
#  '562553',
#  '557211',
#  '549909',
#  '553546',
#  '573083',
#  'C550664',
#  '564755',
#  '537830',
#  '579471',
#  '556813',
#  '575477',
#  '552336',
#  '544205',
#  '569918',
#  '546669',
#  '538883',
#  '575703',
#  '543985',
#  '565117',
#  '540992',
#  'C555254',
#  '550613',
#  'C545033',
#  '563896',
#  '562933',
#  '550471',
#  '577316',
#  '548768',
#  '564221',
#  '547360',
#  '554040',
#  '549296',
#  '559124',
#  '547096',
#  '550468',
#  '570824',
#  '555277',
#  '543826',
#  '559693',
#  '566607',
#  '547397',
#  '547206',
#  'C545449',
#  '549852',
#  '562420',
#  '565056',
#  '571441',
#  '577258',
#  '573397',
#  '561217',
#  'C538124',
#  '546113',
#  '555647',
#  'C545724',
#  '542102',
#  '544089',
#  '551339',
#  'C555358',
#  '570872',
#  'C548355',
#  '560291',
#  '573822',
#  '540372',
#  '565289',
#  '558259',
#  '553612',
#  '538071',
#  '562417',
#  '549730',
#  '555150',
#  'C572410',
#  '542389',
#  '549592',
#  '544928',
#  '543399',
#  '572092',
#  '538951',
#  '560236',
#  '553766',
#  '544565',
#  'C577388',
#  '568369',
#  '545411',
#  '568655',
#  '537955',
#  '554415',
#  '556917',
#  '552231',
#  'C556644',
#  '543099',
#  '572550',
#  '540848',
#  '572655',
#  '547107',
#  '543116',
#  '563909',
#  '565748',
#  '572082',
#  '577039',
#  '541576',
#  '537638',
#  '552694',
#  '562717',
#  '540839',
#  '545036',
#  '543055',
#  '541497',
#  '565994',
#  '560209',
#  '558777',
#  '543660',
#  '564300',
#  '557502',
#  '564199',
#  '541530',
#  '547063',
#  '545428',
#  '543188',
#  '552804',
#  'C549840',
#  '562950',
#  '557481',
#  '554110',
#  '539594',
#  '556323',
#  '547378',
#  '564974',
#  '569415',
#  '567631',
#  '537642',
#  '556927',
#  '541859',
#  '536627',
#  '562033',
#  '547936',
#  '547547',
#  '542719',
#  '538660',
#  '577500',
#  '551531',
#  '549750',
#  '579187',
#  '545895',
#  '537688',
#  '546212',
#  '549927',
#  '554842',
#  '551717',
#  '555854',
#  '551599',
#  '540539',
#  'C566758',
#  '569419',
#  '566257',
#  '553489',
#  '545690',
#  '559525',
#  '559938',
#  '578067',
#  '537378',
#  'C566167',
#  'C574507',
#  '542729',
#  '545445',
#  '554139',
#  '578827',
#  '566482',
#  '575484',
#  '578943',
#  '558240',
#  '559886',
#  '563910',
#  '541932',
#  '544833',
#  '539737',
#  '538566',
#  '570677',
#  '556501',
#  '576388',
#  '576339',
#  '541495',
#  '579572',
#  '561714',
#  '543732',
#  '567324',
#  '567507',
#  '538371',
#  '559497',
#  '563906',
#  '559337',
#  '567378',
#  '545475',
#  '546545',
#  '557616',
#  '567341',
#  '562429',
#  '551174',
#  '541969',
#  '569917',
#  '581495',
#  '548648',
#  '542629',
#  '562607',
#  '572212',
#  '565919',
#  '552533',
#  '546315',
#  '579694',
#  '564714',
#  '562219',
#  '542583',
#  '552323',
#  'C545444',
#  '581219',
#  '559052',
#  '572613',
#  '573266',
#  '556812',
#  '569737',
#  '536524',
#  '574856',
#  '562534',
#  '553901',
#  '580367',
#  '542600',
#  '569650',
#  '547249',
#  '562282',
#  '570127',
#  '569230',
#  '544201',
#  '553369',
#  'C550648',
#  '555477',
#  '575932',
#  '553002',
#  '558862',
#  '566788',
#  '559055',
#  '552687',
#  '559494',
#  '551564',
#  '546158',
#  '564835',
#  '544779',
#  '566326',
#  '578844',
#  '542255',
#  '544778',
#  '539742',
#  'C556793',
#  '554694',
#  'C540393',
#  '546752',
#  '559173',
#  '570488',
#  '552557',
#  '571061',
#  '550914',
#  '550302',
#  '562711',
#  '543602',
#  '537385',
#  '560604',
#  '545721',
#  '563353',
#  '568060',
#  '544668',
#  'C562375',
#  '569137',
#  '546688',
#  '550210',
#  '562102',
#  '579927',
#  '567280',
#  '558526',
#  '556264',
#  '554372',
#  '570428',
#  '576672',
#  '551058',
#  '545601',
#  '545912',
#  '546007',
#  '541280',
#  '571746',
#  '544055',
#  '564092',
#  '559679',
#  '546837',
#  '558885',
#  '551057',
#  '552662',
#  '573778',
#  '553578',
#  '541709',
#  '559491',
#  '570700',
#  '547712',
#  '564817',
#  '550915',
#  '543486',
#  'C554330',
#  '576202',
#  '545460',
#  '556459',
#  '571446',
#  '571745',
#  '544207',
#  '552665',
#  '555147',
#  '577358',
#  '566572',
#  '554813',
#  '563922',
#  '544206',
#  '541949',
#  '556205',
#  '561355',
#  '541592',
#  '545154',
#  '561933',
#  '557672',
#  '546562',
#  '549294',
#  '576063',
#  '556503',
#  '550989',
#  'C562147',
#  '550978',
#  '570086',
#  '564838',
#  '574088',
#  '558119',
#  '580053',
#  '557645',
#  '551387',
#  '554560',
#  '558116',
#  '537738',
#  '570597',
#  '566731',
#  '543451',
#  '551334',
#  '546306',
#  'C559949',
#  '570650',
#  '547828',
#  '542344',
#  '558315',
#  '561329',
#  '575946',
#  'C545456',
#  '552663',
#  '558904',
#  '571713',
#  'C569114',
#  '546498',
#  '564825',
#  '559941',
#  '574076',
#  '539437',
#  '575939',
#  '559639',
#  '540464',
#  '567922',
#  'C550808',
#  '543989',
#  '565840',
#  '557788',
#  '565396',
#  '541008',
#  '560357',
#  '567673',
#  '568781',
#  '569524',
#  '570834',
#  '543022',
#  '577594',
#  '558030',
#  '551343',
#  '561698',
#  '548159',
#  '558262',
#  '573553',
#  '547938',
#  '545681',
#  '571931',
#  '552302',
#  '579512',
#  '557350',
#  '554643',
#  '548194',
#  '559817',
#  '556415',
#  '555015',
#  '539434',
#  '564837',
#  '579297',
#  '537534',
#  '550201',
#  '551953',
#  '564057',
#  '547400',
#  '548559',
#  '571714',
#  '561125',
#  '576618',
#  '566060',
#  '551997',
#  '578031',
#  '571797',
#  '578994',
#  '556073',
#  '576840',
#  '560473',
#  '553899',
#  '564975',
#  '570720',
#  '557560',
#  '564432',
#  '580730',
#  '546367',
#  'C579945',
#  '550953',
#  '570227',
#  '550899',
#  '548673',
#  '540154',
#  '581433',
#  '560225',
#  '558089',
#  '572552',
#  'C564964',
#  '573330',
#  '580115',
#  '552514',
#  '575947',
#  '577512',
#  'C556268',
#  '548860',
#  '536865',
#  '550437',
#  '562608',
#  '568553',
#  'C574548',
#  '576616',
#  '540371',
#  '581498',
#  '571219',
#  '556083',
#  '554028',
#  '568057',
#  '545667',
#  '555836',
#  '566981',
#  '575739',
#  '564552',
#  '548983',
#  '559357',
#  '558923',
#  '560451',
#  '550025',
#  '574700',
#  '559878',
#  '543923',
#  '553543',
#  '547826',
#  '545343',
#  '550474',
#  '557301',
#  '577618',
#  '568134',
#  '577597',
#  '544208',
#  '578331',
#  '555106',
#  '566583',
#  '540026',
#  '537754',
#  '541584',
#  '543013',
#  '560036',
#  '576899',
#  '554013',
#  '555400',
#  '551994',
#  '548522',
#  '553718',
#  '549016',
#  '571216',
#  'C567885',
#  '556821',
#  '571058',
#  '577319',
#  '542349',
#  '562365',
#  '577610',
#  '555109',
#  'C555253',
#  'C543837',
#  '550499',
#  'C555409',
#  '554113',
#  '559557',
#  '544067',
#  'C569911',
#  '549746',
#  '581059',
#  '563561',
#  '575620',
#  '544887',
#  'C542413',
#  '548739',
#  '544075',
#  ...}

# %%
data[data['InvoiceNo']=='562950']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 297488    562950     22752        SET 7 BABUSHKA NESTING BOXES         2
# 297489    562950     22755     SMALL PURPLE BABUSHKA NOTEBOOK         12
# 297490    562950     22753     SMALL YELLOW BABUSHKA NOTEBOOK         12
# 297491    562950     22754        SMALL RED BABUSHKA NOTEBOOK         12
# 297492    562950     22757        LARGE RED BABUSHKA NOTEBOOK         12
# 297493    562950     22758    LARGE PURPLE BABUSHKA NOTEBOOK          12
# 297494    562950     22756     LARGE YELLOW BABUSHKA NOTEBOOK         12
# 297495    562950     23310             BUBBLEGUM RING ASSORTED        36
# 297496    562950     23280  FOLDING BUTTERFLY MIRROR HOT PINK         12
# 297497    562950     22383              LUNCH BAG SUKI DESIGN         10
# 297498    562950     22492             MINI PAINT SET VINTAGE         36
# 297499    562950     71459      HANGING JAM JAR T-LIGHT HOLDER        12
# 297500    562950     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 297501    562950     21175         GIN + TONIC DIET METAL SIGN        12
# 297502    562950     23164                  REGENCY CAKE SLICE         4
# 297503    562950     23245          SET OF 3 REGENCY CAKE TINS         4
# 297504    562950     23171            REGENCY TEA PLATE GREEN         12
# 297505    562950     22697     GREEN REGENCY TEACUP AND SAUCER         6
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 297488  08/11/2011 09:56       8.50     15608.0  United Kingdom
# 297489  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297490  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297491  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297492  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297493  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297494  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297495  08/11/2011 09:56       0.42     15608.0  United Kingdom
# 297496  08/11/2011 09:56       0.83     15608.0  United Kingdom
# 297497  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297498  08/11/2011 09:56       0.65     15608.0  United Kingdom
# 297499  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297500  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297501  08/11/2011 09:56       2.55     15608.0  United Kingdom
# 297502  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297503  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297504  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297505  08/11/2011 09:56       2.95     15608.0  United Kingdom

# %% [markdown]
# #quiz 22386 และ 85099b คือสินค้าอะไร

# %%
set(data[(data['StockCode']=='22386')  ]['Description'])

# %%
set(data[(data['StockCode']=='85099B') ]['Description'])
# Out:
# {'JUMBO BAG RED RETROSPOT'}

# %% [markdown]
# #Hw หา Frequent Item Set และ Association Rules
# - ของช่วงเวลา Chirtmas & New Year(1 Dec -31 Dec)
# - ของประเทศในทวีป Europe
# - ของช่วงเวลา ตรุษจีน ในทวีป Asai (15 jan-15 Feb)
# - ของช่วงเวลา Chirtmas & New Year ในทวีป Europe (1 Dec -31 Dec)
# - ของวันวาเลนไทน์
# - โดยจัดกลุ่มตามประเทศ+เดือ

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %%
df = pd.read_csv(os.path.join(path, '/content/drive/MyDrive/BSC_DPDM23/reduced_marketbasket.csv'), encoding='latin-1')

# %% [markdown]
# ## ข้อ 1. ช่วงเวลา Chirtmas & New Year(1 Dec -31 Dec)

# %%
# Convert รูปแบบเวลาใน column InvoiceDate ให้อยู่ในรูปที่ต้องการ
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%m/%d/%Y %H:%M')

# %%
# Filter December 1st to December 31st
filtered_df = df[(df['InvoiceDate'].dt.month == 12) & (df['InvoiceDate'].dt.day >= 1) & (df['InvoiceDate'].dt.day <= 31)]

#ปริ้นเพื่อตรวจสอบ
print(filtered_df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [68006 rows x 8 columns]

# %% [markdown]
# ## transactions= filtered_df.groupby('InvoiceNo')['StockCode'].apply(list)
# # transactions  ### ถ้าใช้ transactions แทน ##transactions_apply จะเป็นการโชว์ StockCode แทนข้อมูลสินค้า ###

# %%
transactions = filtered_df.groupby('InvoiceNo')['Description'].apply(list).reset_index() #ทำการ group และทำให้ข้อมูลใน Description เป็นlist
transactions_apply = transactions['Description'].apply(lambda x: [str(item) for item in x]) #ใช้ฟังก์ชัน lambda เพื่อแปลงสินค้าทุกชิ้นใน list ของ 'transactions' เป็นข้อความ (string)

# %%
frequentItemset = list(apriori(transactions_apply, min_support=0.035))

for record in frequentItemset:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELIKE GREEN
# Support: 0.0368 (3.68%)
# Rule 1: (None -> ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELIKE GREEN : Confidence=0.0368, Lift=1.0000)
# Rule 2: (ALARM CLOCK BAKELIKE GREEN -> ALARM CLOCK BAKELIKE RED  : Confidence=0.7089, Lift=14.4627)
# Rule 3: (ALARM CLOCK BAKELIKE RED  -> ALARM CLOCK BAKELIKE GREEN : Confidence=0.7517, Lift=14.4627)
#
# yes
# Items: CHOCOLATE HOT WATER BOTTLE, HOT WATER BOTTLE I AM SO POORLY
# Support: 0.0365 (3.65%)
# Rule 1: (None -> CHOCOLATE HOT WATER BOTTLE, HOT WATER BOTTLE I AM SO POORLY : Confidence=0.0365, Lift=1.0000)
# Rule 2: (CHOCOLATE HOT WATER BOTTLE -> HOT WATER BOTTLE I AM SO POORLY : Confidence=0.5163, Lift=9.7484)
# Rule 3: (HOT WATER BOTTLE I AM SO POORLY -> CHOCOLATE HOT WATER BOTTLE : Confidence=0.6894, Lift=9.7484)
#
# yes
# Items: PAPER CHAIN KIT VINTAGE CHRISTMAS, PAPER CHAIN KIT 50'S CHRISTMAS
# Support: 0.0477 (4.77%)
# Rule 1: (None -> PAPER CHAIN KIT VINTAGE CHRISTMAS, PAPER CHAIN KIT 50'S CHRISTMAS  : Confidence=0.0477, Lift=1.0000)
# Rule 2: (PAPER CHAIN KIT 50'S CHRISTMAS  -> PAPER CHAIN KIT VINTAGE CHRISTMAS : Confidence=0.5160, Lift=7.1958)
# Rule 3: (PAPER CHAIN KIT VINTAGE CHRISTMAS -> PAPER CHAIN KIT 50'S CHRISTMAS  : Confidence=0.6651, Lift=7.1958)

# %% [markdown]
# #สรุป เลือกอันที่มีค่าสนับสนุนมากที่สุด
#
#
# Items: PAPER CHAIN KIT VINTAGE CHRISTMAS และ PAPER CHAIN KIT 50'S CHRISTMAS ค่าสนับสนุนคือ 0.0477 หรือ 4.77% ของการทำธุรกรรมทั้งหมด
#
# - เมื่อ 'PAPER CHAIN KIT 50'S CHRISTMAS' ถูกซื้อ มีความมั่นใจ 51.60% ว่า 'PAPER CHAIN KIT VINTAGE CHRISTMAS' จะถูกซื้อด้วย
#
# - เมื่อ 'PAPER CHAIN KIT VINTAGE CHRISTMAS' ถูกซื้อ มีโอกาส 66.51% ว่า 'PAPER CHAIN KIT 50'S CHRISTMAS' จะถูกซื้อด้วย

# %% [markdown]
# ## ข้อ 2. ประเทศในทวีป Europe

# %%
europe_countries = {
    'Austria', 'Belgium', 'Channel Islands','Cyprus', 'Czech Republic', 'Denmark', 'EIRE',
    'European Community', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Italy',
    'Lithuania', 'Malta', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Spain', 'Sweden',
    'Switzerland', 'United Kingdom'
}

# %%
# เลือกประเทศจาก european_countries
filtered_df2 = df[df['Country'].isin(europe_countries)]

# โชว์ datafram เพื่อcheck
print(filtered_df2)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [538358 rows x 8 columns]

# %%
transactions2 = filtered_df2.groupby('InvoiceNo')['Description'].apply(list).reset_index() #ทำการ group และทำให้ข้อมูลใน Description เป็นlist
transactions_apply2 = transactions2['Description'].apply(lambda x: [str(item) for item in x]) #ใช้ฟังก์ชัน lambda เพื่อแปลงสินค้าทุกชิ้นใน list ของ 'transactions' เป็นข้อความ (string)

# %%
frequentItemset2 = list(apriori(transactions_apply2, min_support=0.025))

for record in frequentItemset2:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: ROSES REGENCY TEACUP AND SAUCER , GREEN REGENCY TEACUP AND SAUCER
# Support: 0.0301 (3.01%)
# Rule 1: (None -> ROSES REGENCY TEACUP AND SAUCER , GREEN REGENCY TEACUP AND SAUCER : Confidence=0.0301, Lift=1.0000)
# Rule 2: (GREEN REGENCY TEACUP AND SAUCER -> ROSES REGENCY TEACUP AND SAUCER  : Confidence=0.7402, Lift=17.2054)
# Rule 3: (ROSES REGENCY TEACUP AND SAUCER  -> GREEN REGENCY TEACUP AND SAUCER : Confidence=0.7001, Lift=17.2054)
#
# yes
# Items: JUMBO BAG RED RETROSPOT, JUMBO BAG PINK POLKADOT
# Support: 0.0323 (3.23%)
# Rule 1: (None -> JUMBO BAG RED RETROSPOT, JUMBO BAG PINK POLKADOT : Confidence=0.0323, Lift=1.0000)
# Rule 2: (JUMBO BAG PINK POLKADOT -> JUMBO BAG RED RETROSPOT : Confidence=0.6775, Lift=8.2039)
# Rule 3: (JUMBO BAG RED RETROSPOT -> JUMBO BAG PINK POLKADOT : Confidence=0.3915, Lift=8.2039)
#
# yes
# Items: JUMBO BAG RED RETROSPOT, JUMBO SHOPPER VINTAGE RED PAISLEY
# Support: 0.0265 (2.65%)
# Rule 1: (None -> JUMBO BAG RED RETROSPOT, JUMBO SHOPPER VINTAGE RED PAISLEY : Confidence=0.0265, Lift=1.0000)
# Rule 2: (JUMBO BAG RED RETROSPOT -> JUMBO SHOPPER VINTAGE RED PAISLEY : Confidence=0.3209, Lift=6.9807)
# Rule 3: (JUMBO SHOPPER VINTAGE RED PAISLEY -> JUMBO BAG RED RETROSPOT : Confidence=0.5765, Lift=6.9807)
#
# yes
# Items: JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI
# Support: 0.0285 (2.85%)
# Rule 1: (None -> JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI : Confidence=0.0285, Lift=1.0000)
# Rule 2: (JUMBO BAG RED RETROSPOT -> JUMBO STORAGE BAG SUKI : Confidence=0.3449, Lift=7.4026)
# Rule 3: (JUMBO STORAGE BAG SUKI -> JUMBO BAG RED RETROSPOT : Confidence=0.6113, Lift=7.4026)
#
# yes
# Items: LUNCH BAG  BLACK SKULL., LUNCH BAG RED RETROSPOT
# Support: 0.0251 (2.51%)
# Rule 1: (None -> LUNCH BAG  BLACK SKULL., LUNCH BAG RED RETROSPOT : Confidence=0.0251, Lift=1.0000)
# Rule 2: (LUNCH BAG  BLACK SKULL. -> LUNCH BAG RED RETROSPOT : Confidence=0.5012, Lift=8.1052)
# Rule 3: (LUNCH BAG RED RETROSPOT -> LUNCH BAG  BLACK SKULL. : Confidence=0.4060, Lift=8.1052)

# %% [markdown]
# ## ข้อ 3. ช่วงเวลา ตรุษจีน ในทวีป Asia(15 jan-15 Feb

# %%
asia_countries= {
    'Bahrain', 'Hong Kong', 'Israel', 'Japan', 'Lebanon', 'Saudi Arabia', 'Singapore', 'United Arab Emirates'
}

# %%
# เลือกวันตรุษจีน ในทวีป Asai (15 jan-15 Feb)
filtered_df3 = df[
     (((df['InvoiceDate'].dt.month == 1) & (df['InvoiceDate'].dt.day >= 15)) |
    ((df['InvoiceDate'].dt.month == 2) & (df['InvoiceDate'].dt.day <= 15))) &
    (df['Country'].isin(asia_countries))
]


# โชว์ datafram เพื่อcheck
print(filtered_df3)

# %%
transactions3 = filtered_df3.groupby('InvoiceNo')['Description'].apply(list).reset_index() #ทำการ group และทำให้ข้อมูลใน Description เป็นlist
transactions_apply3 = transactions3['Description'].apply(lambda x: [str(item) for item in x]) #ใช้ฟังก์ชัน lambda เพื่อแปลงสินค้าทุกชิ้นใน list ของ 'transactions' เป็นข้อความ (string)

# %%
frequentItemset3 = list(apriori(transactions_apply3, min_support=0.3))

for record in frequentItemset3:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: BASKET OF TOADSTOOLS, LUNCH BAG RED RETROSPOT
# Support: 0.3333 (33.33%)
# Rule 1: (None -> BASKET OF TOADSTOOLS, LUNCH BAG RED RETROSPOT : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BASKET OF TOADSTOOLS -> LUNCH BAG RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LUNCH BAG RED RETROSPOT -> BASKET OF TOADSTOOLS : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: BASKET OF TOADSTOOLS, SET 3 RETROSPOT TEA,COFFEE,SUGAR
# Support: 0.3333 (33.33%)
# Rule 1: (None -> BASKET OF TOADSTOOLS, SET 3 RETROSPOT TEA,COFFEE,SUGAR : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BASKET OF TOADSTOOLS -> SET 3 RETROSPOT TEA,COFFEE,SUGAR : Confidence=1.0000, Lift=3.0000)
# Rule 3: (SET 3 RETROSPOT TEA,COFFEE,SUGAR -> BASKET OF TOADSTOOLS : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS
# Support: 0.3333 (33.33%)
# Rule 1: (None -> BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BATH BUILDING BLOCK WORD -> JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 3: (JAM MAKING SET WITH JARS -> BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BATH BUILDING BLOCK WORD -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> BATH BUILDING BLOCK WORD : Confidence=0.6667, Lift=2.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BATH BUILDING BLOCK WORD -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
# Rule 3: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> BATH BUILDING BLOCK WORD : Confidence=0.6667, Lift=2.0000)
#
# yes
# Items: BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BEWARE OF THE CAT METAL SIGN  -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> BEWARE OF THE CAT METAL SIGN  : Confidence=0.6667, Lift=2.0000)
#
# yes
# Items: BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BEWARE OF THE CAT METAL SIGN  -> LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LAUNDRY 15C METAL SIGN -> BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BEWARE OF THE CAT METAL SIGN  -> WASHROOM METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (WASHROOM METAL SIGN -> BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: LADIES & GENTLEMEN METAL SIGN, DOORMAT UNION FLAG
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, DOORMAT UNION FLAG : Confidence=0.3333, Lift=1.0000)
# Rule 2: (DOORMAT UNION FLAG -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> DOORMAT UNION FLAG : Confidence=0.6667, Lift=2.0000)
#
# yes
# Items: METAL SIGN TAKE IT OR LEAVE IT , DOORMAT UNION FLAG
# Support: 0.3333 (33.33%)
# Rule 1: (None -> METAL SIGN TAKE IT OR LEAVE IT , DOORMAT UNION FLAG : Confidence=0.3333, Lift=1.0000)
# Rule 2: (DOORMAT UNION FLAG -> METAL SIGN TAKE IT OR LEAVE IT  : Confidence=1.0000, Lift=3.0000)
# Rule 3: (METAL SIGN TAKE IT OR LEAVE IT  -> DOORMAT UNION FLAG : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS : Confidence=0.3333, Lift=1.0000)
# Rule 2: (JAM MAKING SET WITH JARS -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS : Confidence=0.3333, Lift=1.0000)
# Rule 2: (JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
# Rule 3: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
#
# yes
# Items: LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (LADIES & GENTLEMEN METAL SIGN -> LAUNDRY 15C METAL SIGN : Confidence=0.6667, Lift=2.0000)
# Rule 3: (LAUNDRY 15C METAL SIGN -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
#
# yes
# Items: LADIES & GENTLEMEN METAL SIGN, METAL SIGN TAKE IT OR LEAVE IT
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, METAL SIGN TAKE IT OR LEAVE IT  : Confidence=0.3333, Lift=1.0000)
# Rule 2: (LADIES & GENTLEMEN METAL SIGN -> METAL SIGN TAKE IT OR LEAVE IT  : Confidence=0.6667, Lift=2.0000)
# Rule 3: (METAL SIGN TAKE IT OR LEAVE IT  -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (LADIES & GENTLEMEN METAL SIGN -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=0.6667, Lift=1.3333)
# Rule 3: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> LADIES & GENTLEMEN METAL SIGN : Confidence=0.6667, Lift=1.3333)
#
# yes
# Items: WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (LADIES & GENTLEMEN METAL SIGN -> WASHROOM METAL SIGN : Confidence=0.6667, Lift=2.0000)
# Rule 3: (WASHROOM METAL SIGN -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
#
# yes
# Items: WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (WASHROOM METAL SIGN -> LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: SET 3 RETROSPOT TEA,COFFEE,SUGAR, LUNCH BAG RED RETROSPOT
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 RETROSPOT TEA,COFFEE,SUGAR, LUNCH BAG RED RETROSPOT : Confidence=0.3333, Lift=1.0000)
# Rule 2: (LUNCH BAG RED RETROSPOT -> SET 3 RETROSPOT TEA,COFFEE,SUGAR : Confidence=1.0000, Lift=3.0000)
# Rule 3: (SET 3 RETROSPOT TEA,COFFEE,SUGAR -> LUNCH BAG RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN PINK POLKADOT -> MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 3: (MILK PAN RED RETROSPOT -> MILK PAN PINK POLKADOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN PINK POLKADOT -> PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 3: (PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN PINK POLKADOT -> RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 3: (RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN PINK POLKADOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN RED RETROSPOT -> PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 3: (PLASTERS IN TIN SPACEBOY -> MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT
# Support: 0.3333 (33.33%)
# Rule 1: (None -> RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN RED RETROSPOT -> RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 3: (RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, PARTY BUNTING
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, PARTY BUNTING : Confidence=0.3333, Lift=1.0000)
# Rule 2: (PARTY BUNTING -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
# Rule 3: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> PARTY BUNTING : Confidence=0.6667, Lift=2.0000)
#
# yes
# Items: RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY
# Support: 0.3333 (33.33%)
# Rule 1: (None -> RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY : Confidence=0.3333, Lift=1.0000)
# Rule 2: (PLASTERS IN TIN SPACEBOY -> RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 3: (RED RETROSPOT CHILDRENS UMBRELLA -> PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, SET OF 72 PINK HEART PAPER DOILIES
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, SET OF 72 PINK HEART PAPER DOILIES : Confidence=0.3333, Lift=1.0000)
# Rule 2: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> SET OF 72 PINK HEART PAPER DOILIES : Confidence=0.6667, Lift=2.0000)
# Rule 3: (SET OF 72 PINK HEART PAPER DOILIES -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
#
# yes
# Items: BASKET OF TOADSTOOLS, SET 3 RETROSPOT TEA,COFFEE,SUGAR, LUNCH BAG RED RETROSPOT
# Support: 0.3333 (33.33%)
# Rule 1: (None -> BASKET OF TOADSTOOLS, SET 3 RETROSPOT TEA,COFFEE,SUGAR, LUNCH BAG RED RETROSPOT : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BASKET OF TOADSTOOLS -> SET 3 RETROSPOT TEA,COFFEE,SUGAR, LUNCH BAG RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LUNCH BAG RED RETROSPOT -> BASKET OF TOADSTOOLS, SET 3 RETROSPOT TEA,COFFEE,SUGAR : Confidence=1.0000, Lift=3.0000)
# Rule 4: (SET 3 RETROSPOT TEA,COFFEE,SUGAR -> BASKET OF TOADSTOOLS, LUNCH BAG RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 5: (BASKET OF TOADSTOOLS, LUNCH BAG RED RETROSPOT -> SET 3 RETROSPOT TEA,COFFEE,SUGAR : Confidence=1.0000, Lift=3.0000)
# Rule 6: (BASKET OF TOADSTOOLS, SET 3 RETROSPOT TEA,COFFEE,SUGAR -> LUNCH BAG RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 7: (SET 3 RETROSPOT TEA,COFFEE,SUGAR, LUNCH BAG RED RETROSPOT -> BASKET OF TOADSTOOLS : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BATH BUILDING BLOCK WORD -> LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 3: (JAM MAKING SET WITH JARS -> LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
# Rule 4: (LADIES & GENTLEMEN METAL SIGN -> BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
# Rule 5: (BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 6: (LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD -> JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 7: (LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS -> BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BATH BUILDING BLOCK WORD -> SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 3: (JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
# Rule 4: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
# Rule 5: (BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
# Rule 6: (SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD -> JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 7: (SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS -> BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BATH BUILDING BLOCK WORD -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD : Confidence=0.6667, Lift=2.0000)
# Rule 4: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD : Confidence=0.6667, Lift=2.0000)
# Rule 5: (LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
# Rule 6: (SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 7: (SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN -> BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BEWARE OF THE CAT METAL SIGN  -> LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN : Confidence=0.6667, Lift=2.0000)
# Rule 4: (LAUNDRY 15C METAL SIGN -> BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 5: (BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN -> LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 6: (BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 7: (LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN -> BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BEWARE OF THE CAT METAL SIGN  -> WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  : Confidence=0.6667, Lift=2.0000)
# Rule 4: (WASHROOM METAL SIGN -> BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 5: (BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN -> WASHROOM METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 6: (WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 7: (WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN -> BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BEWARE OF THE CAT METAL SIGN  -> WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
# Rule 4: (WASHROOM METAL SIGN -> BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 5: (BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 6: (WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  -> LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 7: (WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN -> BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: LADIES & GENTLEMEN METAL SIGN, METAL SIGN TAKE IT OR LEAVE IT , DOORMAT UNION FLAG
# Support: 0.3333 (33.33%)
# Rule 1: (None -> LADIES & GENTLEMEN METAL SIGN, METAL SIGN TAKE IT OR LEAVE IT , DOORMAT UNION FLAG : Confidence=0.3333, Lift=1.0000)
# Rule 2: (DOORMAT UNION FLAG -> LADIES & GENTLEMEN METAL SIGN, METAL SIGN TAKE IT OR LEAVE IT  : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> METAL SIGN TAKE IT OR LEAVE IT , DOORMAT UNION FLAG : Confidence=0.6667, Lift=2.0000)
# Rule 4: (METAL SIGN TAKE IT OR LEAVE IT  -> LADIES & GENTLEMEN METAL SIGN, DOORMAT UNION FLAG : Confidence=1.0000, Lift=3.0000)
# Rule 5: (LADIES & GENTLEMEN METAL SIGN, DOORMAT UNION FLAG -> METAL SIGN TAKE IT OR LEAVE IT  : Confidence=1.0000, Lift=3.0000)
# Rule 6: (METAL SIGN TAKE IT OR LEAVE IT , DOORMAT UNION FLAG -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 7: (LADIES & GENTLEMEN METAL SIGN, METAL SIGN TAKE IT OR LEAVE IT  -> DOORMAT UNION FLAG : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS : Confidence=0.3333, Lift=1.0000)
# Rule 2: (JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
# Rule 4: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
# Rule 5: (LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
# Rule 6: (SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 7: (SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN -> JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (LADIES & GENTLEMEN METAL SIGN -> WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=0.6667, Lift=2.0000)
# Rule 3: (LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 4: (WASHROOM METAL SIGN -> LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 5: (LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 6: (WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN -> LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 7: (WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
#
# yes
# Items: MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN PINK POLKADOT -> MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 3: (MILK PAN RED RETROSPOT -> MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 4: (PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 5: (MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT -> PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 6: (MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY -> MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 7: (MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN PINK POLKADOT -> RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 3: (MILK PAN RED RETROSPOT -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 4: (RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 5: (MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT -> RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 6: (MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 7: (RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT -> MILK PAN PINK POLKADOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN PINK POLKADOT -> RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 3: (PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 4: (RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 5: (MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY -> RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 6: (MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA -> PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 7: (RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY
# Support: 0.3333 (33.33%)
# Rule 1: (None -> RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN RED RETROSPOT -> RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 3: (PLASTERS IN TIN SPACEBOY -> RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 4: (RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 5: (MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY -> RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 6: (RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT -> PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 7: (RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY -> MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS
# Support: 0.3333 (33.33%)
# Rule 1: (None -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BATH BUILDING BLOCK WORD -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 3: (JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
# Rule 4: (LADIES & GENTLEMEN METAL SIGN -> SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
# Rule 5: (SET 3 PAPER VINTAGE CHICK PAPER EGG -> LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=0.6667, Lift=2.0000)
# Rule 6: (BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 7: (LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD -> SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 8: (SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD -> LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 9: (LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
# Rule 10: (SET 3 PAPER VINTAGE CHICK PAPER EGG, JAM MAKING SET WITH JARS -> LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
# Rule 11: (SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN -> BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 12: (LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS -> SET 3 PAPER VINTAGE CHICK PAPER EGG : Confidence=1.0000, Lift=2.0000)
# Rule 13: (SET 3 PAPER VINTAGE CHICK PAPER EGG, BATH BUILDING BLOCK WORD, JAM MAKING SET WITH JARS -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 14: (SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, BATH BUILDING BLOCK WORD -> JAM MAKING SET WITH JARS : Confidence=1.0000, Lift=3.0000)
# Rule 15: (SET 3 PAPER VINTAGE CHICK PAPER EGG, LADIES & GENTLEMEN METAL SIGN, JAM MAKING SET WITH JARS -> BATH BUILDING BLOCK WORD : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN
# Support: 0.3333 (33.33%)
# Rule 1: (None -> WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=0.3333, Lift=1.0000)
# Rule 2: (BEWARE OF THE CAT METAL SIGN  -> WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 3: (LADIES & GENTLEMEN METAL SIGN -> WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN : Confidence=0.6667, Lift=2.0000)
# Rule 4: (LAUNDRY 15C METAL SIGN -> LADIES & GENTLEMEN METAL SIGN, WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
# Rule 5: (WASHROOM METAL SIGN -> BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 6: (BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN -> WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 7: (BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 8: (WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  -> LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 9: (LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
# Rule 10: (WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN -> BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 11: (WASHROOM METAL SIGN, LAUNDRY 15C METAL SIGN -> BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 12: (BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN -> WASHROOM METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 13: (WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LADIES & GENTLEMEN METAL SIGN -> LAUNDRY 15C METAL SIGN : Confidence=1.0000, Lift=3.0000)
# Rule 14: (WASHROOM METAL SIGN, BEWARE OF THE CAT METAL SIGN , LAUNDRY 15C METAL SIGN -> LADIES & GENTLEMEN METAL SIGN : Confidence=1.0000, Lift=2.0000)
# Rule 15: (WASHROOM METAL SIGN, LADIES & GENTLEMEN METAL SIGN, LAUNDRY 15C METAL SIGN -> BEWARE OF THE CAT METAL SIGN  : Confidence=1.0000, Lift=3.0000)
#
# yes
# Items: MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY
# Support: 0.3333 (33.33%)
# Rule 1: (None -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=0.3333, Lift=1.0000)
# Rule 2: (MILK PAN PINK POLKADOT -> RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 3: (MILK PAN RED RETROSPOT -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 4: (PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 5: (RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 6: (MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT -> RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 7: (MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY -> RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 8: (MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA -> MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 9: (MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 10: (RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT -> MILK PAN PINK POLKADOT, PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 11: (RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 12: (MILK PAN PINK POLKADOT, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY -> RED RETROSPOT CHILDRENS UMBRELLA : Confidence=1.0000, Lift=3.0000)
# Rule 13: (MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT -> PLASTERS IN TIN SPACEBOY : Confidence=1.0000, Lift=3.0000)
# Rule 14: (MILK PAN PINK POLKADOT, RED RETROSPOT CHILDRENS UMBRELLA, PLASTERS IN TIN SPACEBOY -> MILK PAN RED RETROSPOT : Confidence=1.0000, Lift=3.0000)
# Rule 15: (RED RETROSPOT CHILDRENS UMBRELLA, MILK PAN RED RETROSPOT, PLASTERS IN TIN SPACEBOY -> MILK PAN PINK POLKADOT : Confidence=1.0000, Lift=3.0000)

# %% [markdown]
# ## ข้อ 4. ช่วงเวลา Chirtmas & New Year ในทวีป Europe (1 Dec -31 Dec)

# %%
# เลือกช่วงเวลา Chirtmas & New Year ในทวีป Europe (1 Dec -31 Dec)
filtered_df4 = df[
     (df['InvoiceDate'].dt.month == 12)  &
    (df['Country'].isin(europe_countries))
]


# โชว์ datafram เพื่อcheck
print(filtered_df4)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [67852 rows x 8 columns]

# %%
transactions4 = filtered_df4.groupby('InvoiceNo')['Description'].apply(list).reset_index() #ทำการ group และทำให้ข้อมูลใน Description เป็นlist
transactions_apply4 = transactions4['Description'].apply(lambda x: [str(item) for item in x]) #ใช้ฟังก์ชัน lambda เพื่อแปลงสินค้าทุกชิ้นใน list ของ 'transactions' เป็นข้อความ (string)

# %%
frequentItemset4 = list(apriori(transactions_apply4, min_support=0.035))

for record in frequentItemset4:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELIKE GREEN
# Support: 0.0367 (3.67%)
# Rule 1: (None -> ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELIKE GREEN : Confidence=0.0367, Lift=1.0000)
# Rule 2: (ALARM CLOCK BAKELIKE GREEN -> ALARM CLOCK BAKELIKE RED  : Confidence=0.7070, Lift=14.4602)
# Rule 3: (ALARM CLOCK BAKELIKE RED  -> ALARM CLOCK BAKELIKE GREEN : Confidence=0.7500, Lift=14.4602)
#
# yes
# Items: CHOCOLATE HOT WATER BOTTLE, HOT WATER BOTTLE I AM SO POORLY
# Support: 0.0367 (3.67%)
# Rule 1: (None -> CHOCOLATE HOT WATER BOTTLE, HOT WATER BOTTLE I AM SO POORLY : Confidence=0.0367, Lift=1.0000)
# Rule 2: (CHOCOLATE HOT WATER BOTTLE -> HOT WATER BOTTLE I AM SO POORLY : Confidence=0.5163, Lift=9.7067)
# Rule 3: (HOT WATER BOTTLE I AM SO POORLY -> CHOCOLATE HOT WATER BOTTLE : Confidence=0.6894, Lift=9.7067)
#
# yes
# Items: PAPER CHAIN KIT VINTAGE CHRISTMAS, PAPER CHAIN KIT 50'S CHRISTMAS
# Support: 0.0479 (4.79%)
# Rule 1: (None -> PAPER CHAIN KIT VINTAGE CHRISTMAS, PAPER CHAIN KIT 50'S CHRISTMAS  : Confidence=0.0479, Lift=1.0000)
# Rule 2: (PAPER CHAIN KIT 50'S CHRISTMAS  -> PAPER CHAIN KIT VINTAGE CHRISTMAS : Confidence=0.5160, Lift=7.1650)
# Rule 3: (PAPER CHAIN KIT VINTAGE CHRISTMAS -> PAPER CHAIN KIT 50'S CHRISTMAS  : Confidence=0.6651, Lift=7.1650)

# %% [markdown]
# ## ข้อ 5. วันวาเลนไทน์

# %%
# เลือกเฉพาะวันวาเลนไทน์
filtered_df5 = df[(df['InvoiceDate'].dt.month == 2) & (df['InvoiceDate'].dt.day == 14) ]

# โชว์ datafram เพื่อcheck
print(filtered_df5)
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 88847    543821     22926      IVORY GIANT GARDEN THERMOMETER         2
# 88848    543821     22928     YELLOW GIANT GARDEN THERMOMETER         2
# 88849    543821     22925       BLUE GIANT GARDEN THERMOMETER         2
# 88850    543821     85175               CACTI T-LIGHT CANDLES        16
# 88851    543821     22456     NATURAL SLATE CHALKBOARD LARGE          3
# ...         ...       ...                                 ...       ...
# 89950    543979     21889              WOODEN BOX OF DOMINOES         1
# 89951    543979     85176          SEWING SUSAN 21 NEEDLE SET         1
# 89952    543979     37446  MINI CAKE STAND WITH HANGING CAKES         1
# 89953    543979     21657     MILK BOTTLE WITH GLASS STOPPER          1
# 89954   C543980     22728           ALARM CLOCK BAKELIKE PINK        -1
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 88847 2011-02-14 09:24:00       5.95     17667.0  United Kingdom
# 88848 2011-02-14 09:24:00       5.95     17667.0  United Kingdom
# 88849 2011-02-14 09:24:00       5.95     17667.0  United Kingdom
# 88850 2011-02-14 09:24:00       0.42     17667.0  United Kingdom
# 88851 2011-02-14 09:24:00       4.95     17667.0  United Kingdom
# ...                   ...        ...         ...             ...
# 89950 2011-02-14 15:43:00       1.25     14606.0  United Kingdom
# 89951 2011-02-14 15:43:00       0.85     14606.0  United Kingdom
# 89952 2011-02-14 15:43:00       1.45     14606.0  United Kingdom
# 89953 2011-02-14 15:43:00       6.95     14606.0  United Kingdom
# 89954 2011-02-14 16:39:00       3.75     14189.0  United Kingdom
#
# [1108 rows x 8 columns]

# %%
transactions5 = filtered_df5.groupby('InvoiceNo')['Description'].apply(list).reset_index() #ทำการ group และทำให้ข้อมูลใน Description เป็นlist
transactions_apply5 = transactions5['Description'].apply(lambda x: [str(item) for item in x]) #ใช้ฟังก์ชัน lambda เพื่อแปลงสินค้าทุกชิ้นใน list ของ 'transactions' เป็นข้อความ (string)

# %%
frequentItemset5 = list(apriori(transactions_apply5, min_support=0.09))

for record in frequentItemset5:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: SET OF 3 CAKE TINS PANTRY DESIGN , HOMEMADE JAM SCENTED CANDLES
# Support: 0.0909 (9.09%)
# Rule 1: (None -> SET OF 3 CAKE TINS PANTRY DESIGN , HOMEMADE JAM SCENTED CANDLES : Confidence=0.0909, Lift=1.0000)
# Rule 2: (HOMEMADE JAM SCENTED CANDLES -> SET OF 3 CAKE TINS PANTRY DESIGN  : Confidence=1.0000, Lift=6.8750)
# Rule 3: (SET OF 3 CAKE TINS PANTRY DESIGN  -> HOMEMADE JAM SCENTED CANDLES : Confidence=0.6250, Lift=6.8750)
#
# yes
# Items: SET OF 6 SPICE TINS PANTRY DESIGN, SET OF 3 CAKE TINS PANTRY DESIGN
# Support: 0.0909 (9.09%)
# Rule 1: (None -> SET OF 6 SPICE TINS PANTRY DESIGN, SET OF 3 CAKE TINS PANTRY DESIGN  : Confidence=0.0909, Lift=1.0000)
# Rule 2: (SET OF 3 CAKE TINS PANTRY DESIGN  -> SET OF 6 SPICE TINS PANTRY DESIGN : Confidence=0.6250, Lift=5.7292)
# Rule 3: (SET OF 6 SPICE TINS PANTRY DESIGN -> SET OF 3 CAKE TINS PANTRY DESIGN  : Confidence=0.8333, Lift=5.7292)

# %% [markdown]
# ## ข้อ 6. โดยจัดกลุ่มตามประเทศ+เดือน

# %%
df6 = pd.read_csv(os.path.join(path, '/content/drive/MyDrive/BSC_DPDM23/reduced_marketbasket.csv'), encoding='latin-1')

# %%
# Convert รูปแบบเวลาใน column InvoiceDate ให้อยู่ในรูปที่ต้องการ
df6['InvoiceDate'] = pd.to_datetime(df6['InvoiceDate'], format='%m/%d/%Y %H:%M')

# %%
df6['Month'] = df6['InvoiceDate'].dt.month

# df6['Year'] = df6['InvoiceDate'].dt.year   #ถ้าต้องการ"ปี"ด้วย

# %%
# transactions_Mon_Con = df6.groupby(['Country', 'Month'])['StockCode'].apply(list)

# %%
transactions6 = df6.groupby(['Country', 'Month'])['StockCode'].apply(list) #ทำการ group และทำให้ข้อมูลใน Description เป็นlist  สามารถเพิ่มปี ได้โดย 'Year'
# transactions_apply6 = transactions6['Description'].apply(lambda x: [str(item) for item in x]) #ใช้ฟังก์ชัน lambda เพื่อแปลงสินค้าทุกชิ้นใน list ของ 'transactions' เป็นข้อความ (string

# %%
frequentItemset6 = list(apriori(transactions6, min_support=0.30))

for record in frequentItemset6:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: POST, 22326
# Support: 0.3209 (32.09%)
# Rule 1: (None -> POST, 22326 : Confidence=0.3209, Lift=1.0000)
# Rule 2: (22326 -> POST : Confidence=0.8407, Lift=1.4638)
# Rule 3: (POST -> 22326 : Confidence=0.5588, Lift=1.4638)
#
# yes
# Items: POST, 22423
# Support: 0.3142 (31.42%)
# Rule 1: (None -> POST, 22423 : Confidence=0.3142, Lift=1.0000)
# Rule 2: (22423 -> POST : Confidence=0.6838, Lift=1.1907)
# Rule 3: (POST -> 22423 : Confidence=0.5471, Lift=1.1907)
#
# yes
# Items: 22630, 22629
# Support: 0.3007 (30.07%)
# Rule 1: (None -> 22630, 22629 : Confidence=0.3007, Lift=1.0000)
# Rule 2: (22629 -> 22630 : Confidence=0.8812, Lift=2.5572)
# Rule 3: (22630 -> 22629 : Confidence=0.8725, Lift=2.5572)

# %% [markdown]
# ### 6.1 ช่วงเวลา Chirtmas & New Year(1 Dec -31 Dec)

# %%
# Filter December 1st to December 31st
filtered_df61 = df6[(df6['InvoiceDate'].dt.month == 12) & (df6['InvoiceDate'].dt.day >= 1) & (df6['InvoiceDate'].dt.day <= 31)]

# %%
transactions61 = filtered_df61.groupby(['Country', 'Month'])['StockCode'].apply(list)

# %%
frequentItemset61 = list(apriori(transactions61, min_support=0.3))

for record in frequentItemset61:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: 20750, POST
# Support: 0.3333 (33.33%)
# Rule 1: (None -> 20750, POST : Confidence=0.3333, Lift=1.0000)
# Rule 2: (20750 -> POST : Confidence=0.9000, Lift=1.7357)
# Rule 3: (POST -> 20750 : Confidence=0.6429, Lift=1.7357)
#
# yes
# Items: 22728, 22727
# Support: 0.3333 (33.33%)
# Rule 1: (None -> 22727, 22728 : Confidence=0.3333, Lift=1.0000)
# Rule 2: (22727 -> 22728 : Confidence=1.0000, Lift=3.0000)
# Rule 3: (22728 -> 22727 : Confidence=1.0000, Lift=3.0000)

# %% [markdown]
# ### 6.2 ช่วงเวลา Chirtmas & New Year(1 Dec -31 Dec)

# %%
# เลือกประเทศจาก european_countries
filtered_df62 = df6[df6['Country'].isin(europe_countries)]

# %%
transactions62 = filtered_df62.groupby(['Country', 'Month'])['StockCode'].apply(list)

# %%
transactions62
# Out:
# Country         Month
# Austria         2        [20713, 21931, 22553, 20724, 20719, 20726, 223...
#                 3        [22556, 22139, 84879, POST, 22582, 22584, 2213...
#                 4        [47566B, 47599A, 22128, 21977, POST, 23053, 23...
#                 5        [47566, 47590B, 47590A, 21172, 21207, POST, 21...
#                 6                                           [22697, 22357]
#                                                ...
# United Kingdom  8        [22075, 85049E, 21385, 84970L, 84970S, 84978, ...
#                 9        [20677, 22128, 21067, 22423, 15060B, 23245, 22...
#                 10       [79321, 21154, 21790, 23284, 23355, 22207, 221...
#                 11       [21314, 21704, 21791, 21892, 21915, 22065, 223...
#                 12       [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# Name: StockCode, Length: 226, dtype: object

# %%
frequentItemset62 = list(apriori(transactions62, min_support=0.4))

for record in frequentItemset62:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: POST, 22326
# Support: 0.4115 (41.15%)
# Rule 1: (None -> POST, 22326 : Confidence=0.4115, Lift=1.0000)
# Rule 2: (22326 -> POST : Confidence=0.9208, Lift=1.2689)
# Rule 3: (POST -> 22326 : Confidence=0.5671, Lift=1.2689)

# %% [markdown]
# ### 6.3 ช่วงเวลา Chirtmas & New Year(1 Dec -31 Dec)

# %%
filtered_df63 = df6[
     (((df6['InvoiceDate'].dt.month == 1) & (df6['InvoiceDate'].dt.day >= 15)) |
    ((df6['InvoiceDate'].dt.month == 2) & (df6['InvoiceDate'].dt.day <= 15))) &
    (df6['Country'].isin(asia_countries))
]

# %%
transactions63 = filtered_df63.groupby(['Country', 'Month'])['StockCode'].apply(list)

# %%
frequentItemset63 = list(apriori(transactions63, min_support=0.35))

for record in frequentItemset63:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: 22202, 20682
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22202, 20682 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20682 -> 22202 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22202 -> 20682 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22203, 20682
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22203, 20682 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20682 -> 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22203 -> 20682 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22551, 20682
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22551, 20682 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20682 -> 22551 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22551 -> 20682 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 20725, 21216
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 20725, 21216 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20725 -> 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21216 -> 20725 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21439, 20725
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21439, 20725 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20725 -> 21439 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21439 -> 20725 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 20725, 22620
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 20725, 22620 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20725 -> 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22620 -> 20725 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 82551, 21165
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82551, 21165 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21165 -> 82551 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82551 -> 21165 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21165, 82552
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21165, 82552 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21165 -> 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82552 -> 21165 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21165, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21165, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21165 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (85150 -> 21165 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 21439, 21216
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21439, 21216 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21216 -> 21439 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21439 -> 21216 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21216, 22620
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21216, 22620 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21216 -> 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22620 -> 21216 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21439, 22620
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21439, 22620 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21439 -> 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22620 -> 21439 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22957, 21756
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 21756 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21756 -> 22957 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (22957 -> 21756 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 21756, 22960
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21756, 22960 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21756 -> 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22960 -> 21756 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21756, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21756, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21756 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (85150 -> 21756 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 22202, 22203
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22202, 22203 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22202 -> 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22203 -> 22202 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22551, 22202
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22551, 22202 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22202 -> 22551 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22551 -> 22202 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22551, 22203
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22551, 22203 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22203 -> 22551 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22551 -> 22203 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 48138, 22413
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 48138, 22413 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22413 -> 48138 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (48138 -> 22413 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22413, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22413, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22413 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (85150 -> 22413 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 22957, 22960
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 22960 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22957 -> 22960 : Confidence=0.6667, Lift=1.6667)
# Rule 3: (22960 -> 22957 : Confidence=1.0000, Lift=1.6667)
#
# yes
# Items: 22957, 47566
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 47566 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22957 -> 47566 : Confidence=0.6667, Lift=1.6667)
# Rule 3: (47566 -> 22957 : Confidence=1.0000, Lift=1.6667)
#
# yes
# Items: 22957, 84988
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 84988 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22957 -> 84988 : Confidence=0.6667, Lift=1.6667)
# Rule 3: (84988 -> 22957 : Confidence=1.0000, Lift=1.6667)
#
# yes
# Items: 22957, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22957 -> 85150 : Confidence=0.6667, Lift=1.1111)
# Rule 3: (85150 -> 22957 : Confidence=0.6667, Lift=1.1111)
#
# yes
# Items: 85150, 22960
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22960, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22960 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (85150 -> 22960 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 48138, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 48138, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (48138 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (85150 -> 48138 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 82551, 82552
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82551, 82552 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (82551 -> 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82552 -> 82551 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 82551, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82551, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (82551 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (85150 -> 82551 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 82552, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82552, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (82552 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 3: (85150 -> 82552 : Confidence=0.6667, Lift=1.6667)
#
# yes
# Items: 22202, 22203, 20682
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22202, 22203, 20682 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20682 -> 22202, 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22202 -> 22203, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22203 -> 22202, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (22202, 20682 -> 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (22203, 20682 -> 22202 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (22202, 22203 -> 20682 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22551, 22202, 20682
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22551, 22202, 20682 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20682 -> 22551, 22202 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22202 -> 22551, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22551 -> 22202, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (22202, 20682 -> 22551 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (22551, 20682 -> 22202 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (22551, 22202 -> 20682 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22551, 22203, 20682
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22551, 22203, 20682 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20682 -> 22551, 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22203 -> 22551, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22551 -> 22203, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (22203, 20682 -> 22551 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (22551, 20682 -> 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (22551, 22203 -> 20682 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21439, 20725, 21216
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21439, 20725, 21216 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20725 -> 21439, 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21216 -> 21439, 20725 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (21439 -> 20725, 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (20725, 21216 -> 21439 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (21439, 20725 -> 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (21439, 21216 -> 20725 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 20725, 21216, 22620
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 20725, 21216, 22620 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20725 -> 21216, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21216 -> 20725, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22620 -> 20725, 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (20725, 21216 -> 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (20725, 22620 -> 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (21216, 22620 -> 20725 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21439, 20725, 22620
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21439, 20725, 22620 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20725 -> 21439, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21439 -> 20725, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22620 -> 21439, 20725 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (21439, 20725 -> 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (20725, 22620 -> 21439 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (21439, 22620 -> 20725 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 82551, 21165, 82552
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82551, 21165, 82552 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21165 -> 82551, 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82551 -> 21165, 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (82552 -> 82551, 21165 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (82551, 21165 -> 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (21165, 82552 -> 82551 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (82551, 82552 -> 21165 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 82551, 21165, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82551, 21165, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21165 -> 82551, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82551 -> 21165, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (85150 -> 82551, 21165 : Confidence=0.6667, Lift=1.6667)
# Rule 5: (82551, 21165 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 6: (21165, 85150 -> 82551 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (82551, 85150 -> 21165 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21165, 85150, 82552
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21165, 85150, 82552 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21165 -> 82552, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82552 -> 21165, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (85150 -> 21165, 82552 : Confidence=0.6667, Lift=1.6667)
# Rule 5: (21165, 82552 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 6: (21165, 85150 -> 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (82552, 85150 -> 21165 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21439, 21216, 22620
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21439, 21216, 22620 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21216 -> 21439, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21439 -> 21216, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22620 -> 21439, 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (21439, 21216 -> 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (21216, 22620 -> 21439 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (21439, 22620 -> 21216 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22957, 21756, 22960
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 21756, 22960 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21756 -> 22957, 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22957 -> 21756, 22960 : Confidence=0.6667, Lift=1.6667)
# Rule 4: (22960 -> 22957, 21756 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (22957, 21756 -> 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (21756, 22960 -> 22957 : Confidence=1.0000, Lift=1.6667)
# Rule 7: (22957, 22960 -> 21756 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22957, 21756, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 21756, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21756 -> 22957, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22957 -> 21756, 85150 : Confidence=0.6667, Lift=1.6667)
# Rule 4: (85150 -> 22957, 21756 : Confidence=0.6667, Lift=1.6667)
# Rule 5: (22957, 21756 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 6: (21756, 85150 -> 22957 : Confidence=1.0000, Lift=1.6667)
# Rule 7: (22957, 85150 -> 21756 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 85150, 21756, 22960
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21756, 22960, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21756 -> 22960, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22960 -> 21756, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (85150 -> 21756, 22960 : Confidence=0.6667, Lift=1.6667)
# Rule 5: (21756, 22960 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 6: (21756, 85150 -> 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (85150, 22960 -> 21756 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22551, 22202, 22203
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22551, 22202, 22203 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22202 -> 22551, 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22203 -> 22551, 22202 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22551 -> 22202, 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (22202, 22203 -> 22551 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (22551, 22202 -> 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (22551, 22203 -> 22202 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 48138, 22413, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 48138, 22413, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22413 -> 48138, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (48138 -> 22413, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (85150 -> 48138, 22413 : Confidence=0.6667, Lift=1.6667)
# Rule 5: (48138, 22413 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 6: (22413, 85150 -> 48138 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (48138, 85150 -> 22413 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22957, 22960, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 22960, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (22957 -> 85150, 22960 : Confidence=0.6667, Lift=1.6667)
# Rule 3: (22960 -> 22957, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (85150 -> 22957, 22960 : Confidence=0.6667, Lift=1.6667)
# Rule 5: (22957, 22960 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 6: (22957, 85150 -> 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (85150, 22960 -> 22957 : Confidence=1.0000, Lift=1.6667)
#
# yes
# Items: 82551, 82552, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82551, 82552, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (82551 -> 82552, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82552 -> 82551, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (85150 -> 82551, 82552 : Confidence=0.6667, Lift=1.6667)
# Rule 5: (82551, 82552 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 6: (82551, 85150 -> 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (82552, 85150 -> 82551 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22551, 22202, 22203, 20682
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22551, 22202, 22203, 20682 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20682 -> 22551, 22202, 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22202 -> 22551, 22203, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (22203 -> 22551, 22202, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (22551 -> 22202, 22203, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (22202, 20682 -> 22551, 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (22203, 20682 -> 22551, 22202 : Confidence=1.0000, Lift=2.5000)
# Rule 8: (22551, 20682 -> 22202, 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 9: (22202, 22203 -> 22551, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 10: (22551, 22202 -> 22203, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 11: (22551, 22203 -> 22202, 20682 : Confidence=1.0000, Lift=2.5000)
# Rule 12: (22202, 22203, 20682 -> 22551 : Confidence=1.0000, Lift=2.5000)
# Rule 13: (22551, 22202, 20682 -> 22203 : Confidence=1.0000, Lift=2.5000)
# Rule 14: (22551, 22203, 20682 -> 22202 : Confidence=1.0000, Lift=2.5000)
# Rule 15: (22551, 22202, 22203 -> 20682 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 21439, 20725, 21216, 22620
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 21439, 20725, 21216, 22620 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (20725 -> 21439, 21216, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (21216 -> 21439, 20725, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (21439 -> 20725, 21216, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (22620 -> 21439, 20725, 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 6: (20725, 21216 -> 21439, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (21439, 20725 -> 21216, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 8: (20725, 22620 -> 21439, 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 9: (21439, 21216 -> 20725, 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 10: (21216, 22620 -> 21439, 20725 : Confidence=1.0000, Lift=2.5000)
# Rule 11: (21439, 22620 -> 20725, 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 12: (21439, 20725, 21216 -> 22620 : Confidence=1.0000, Lift=2.5000)
# Rule 13: (20725, 21216, 22620 -> 21439 : Confidence=1.0000, Lift=2.5000)
# Rule 14: (21439, 20725, 22620 -> 21216 : Confidence=1.0000, Lift=2.5000)
# Rule 15: (21439, 21216, 22620 -> 20725 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 82551, 21165, 85150, 82552
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 82551, 21165, 85150, 82552 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21165 -> 82551, 82552, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (82551 -> 21165, 85150, 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 4: (82552 -> 82551, 21165, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (85150 -> 82551, 21165, 82552 : Confidence=0.6667, Lift=1.6667)
# Rule 6: (82551, 21165 -> 82552, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (21165, 82552 -> 82551, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 8: (21165, 85150 -> 82551, 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 9: (82551, 82552 -> 21165, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 10: (82551, 85150 -> 21165, 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 11: (82552, 85150 -> 82551, 21165 : Confidence=1.0000, Lift=2.5000)
# Rule 12: (82551, 21165, 82552 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 13: (82551, 21165, 85150 -> 82552 : Confidence=1.0000, Lift=2.5000)
# Rule 14: (21165, 85150, 82552 -> 82551 : Confidence=1.0000, Lift=2.5000)
# Rule 15: (82551, 82552, 85150 -> 21165 : Confidence=1.0000, Lift=2.5000)
#
# yes
# Items: 22957, 21756, 22960, 85150
# Support: 0.4000 (40.00%)
# Rule 1: (None -> 22957, 21756, 22960, 85150 : Confidence=0.4000, Lift=1.0000)
# Rule 2: (21756 -> 22957, 22960, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 3: (22957 -> 85150, 21756, 22960 : Confidence=0.6667, Lift=1.6667)
# Rule 4: (22960 -> 22957, 21756, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 5: (85150 -> 22957, 21756, 22960 : Confidence=0.6667, Lift=1.6667)
# Rule 6: (22957, 21756 -> 85150, 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 7: (21756, 22960 -> 22957, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 8: (21756, 85150 -> 22957, 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 9: (22957, 22960 -> 21756, 85150 : Confidence=1.0000, Lift=2.5000)
# Rule 10: (22957, 85150 -> 21756, 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 11: (85150, 22960 -> 22957, 21756 : Confidence=1.0000, Lift=2.5000)
# Rule 12: (22957, 21756, 22960 -> 85150 : Confidence=1.0000, Lift=1.6667)
# Rule 13: (22957, 21756, 85150 -> 22960 : Confidence=1.0000, Lift=2.5000)
# Rule 14: (85150, 21756, 22960 -> 22957 : Confidence=1.0000, Lift=1.6667)
# Rule 15: (22957, 22960, 85150 -> 21756 : Confidence=1.0000, Lift=2.5000)

# %% [markdown]
# ### 6.4 ช่วงเวลา Chirtmas & New Year(1 Dec -31 Dec)

# %%
filtered_df64 = df6[
     (df6['InvoiceDate'].dt.month == 12)  &
    (df6['Country'].isin(europe_countries))
]

# %%
transactions64 = filtered_df64.groupby(['Country', 'Month'])['StockCode'].apply(list)

# %%
frequentItemset64 = list(apriori(transactions64, min_support=0.4))

for record in frequentItemset64:
    if len(record.items) > 1:
        print('yes')
        print(f"Items: {', '.join(record.items)}")
        print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

        for i, stat in enumerate(record.ordered_statistics, 1):
            items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
            items_add = ', '.join(stat.items_add)
            confidence = stat.confidence
            lift = stat.lift

            print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
        print()
# Out:
# yes
# Items: 20750, POST
# Support: 0.4091 (40.91%)
# Rule 1: (None -> 20750, POST : Confidence=0.4091, Lift=1.0000)
# Rule 2: (20750 -> POST : Confidence=0.9000, Lift=1.4143)
# Rule 3: (POST -> 20750 : Confidence=0.6429, Lift=1.4143)

# %% [markdown]
# ### 6.5 ช่วงเวลา Chirtmas & New Year(1 Dec -31 Dec)

# %%
filtered_df65 = df6[(df6['InvoiceDate'].dt.month == 2) & (df6['InvoiceDate'].dt.day == 14) ]

# %%
transactions65 = filtered_df65.groupby(['Country', 'Month'])['StockCode'].apply(list)

# %%
min_sup = 0.5
frequentItemsets_va= list(apriori(transactions65,min_support = min_sup))
for i in frequentItemsets_va:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'20719', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22383'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22383'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22722'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22722'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22957'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22957'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22383', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22383', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22661', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22661', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22662', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22722', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22722', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22957', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22383', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22383', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22661', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22661', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22662', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22722', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22722', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22957', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22195', '21832'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22195', '21832'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'21832'}), items_add=frozenset({'22195'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22195'}), items_add=frozenset({'21832'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22383', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22383', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22383', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22383', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '22383'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22383'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22722', '22383'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22722', '22383'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22957', '22383'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '22383'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22661', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22661', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22722', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22722', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22957', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22722', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22722', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22957', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '22722'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22722'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '22957'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22957'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22722', '22957'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22722', '22957'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22965', '84380'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22965', '84380'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'22965'}), items_add=frozenset({'84380'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'84380'}), items_add=frozenset({'22965'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20728', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22383', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22383', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22383', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22661', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22661', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22662', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22662', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22662', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719', '22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22722', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22722', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22722', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22957', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22957', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'20719', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22383', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22383', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22383', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22661', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22661', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22661', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20728'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22662', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22662', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22662', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719', '22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20728'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22722', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22722', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22722', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22957', '20728'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22957', '20728'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20719', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22383', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22383', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '22661'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22383', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22383', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22383', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '22662'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720', '22383'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720', '22383'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719', '22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '22383'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22383', '22722'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22383', '22722'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22722', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '22383'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22383', '22957'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22383', '22957'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20719', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '22383'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22661', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22661', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22661', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '22662'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719', '22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '22661'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22661', '22722'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22661', '22722'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22722', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '22661'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22661', '22957'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22661', '22957'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20719', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '22661'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719', '22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '22662'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22722', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22722', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22722', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '22662'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22957', '22662'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22957', '22662'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20719', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719', '22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '22662'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720', '22722'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720', '22722'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719', '22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '22722'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22720', '22957'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22720', '22957'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22720', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20719', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719', '22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '22957'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'20719', '22722', '22957'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '22722', '22957'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22722', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20719', '22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '22957'}), items_add=frozenset({'20719'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22383', '20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22383', '20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22383', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22383', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20728', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22661', '20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22661', '20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22661', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20728', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22662', '20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22662', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22662', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20728', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22662'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22720', '20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22720', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22720', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'20728', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22720'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22722', '20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22722', '20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22722', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22722', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20728', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'22957', '20728', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '20728', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22957', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20728', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'20728'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20726'}), confidence=1.0, lift=2.0)])
# yes
# ...
# yes
# RelationRecord(items=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383', '22661'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383', '22661'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22957', '22662', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22957', '20728', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22662', '20728', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22957', '22662', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'22957', '20728', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'22957', '22662', '20728', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'22662', '20728', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'22957', '22662', '20719', '22720', '22722', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20728'}), items_add=frozenset({'22957', '22662', '20719', '22720', '22722', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'22957', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20728'}), items_add=frozenset({'22957', '22662', '20719', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'22957', '22662', '20719', '22720', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'22662', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '22661'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '22662'}), items_add=frozenset({'22957', '20728', '20719', '2272 ...
# yes
# RelationRecord(items=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '22661', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '22661', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22957', '22662', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22957', '20728', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22957', '22662', '20728', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22662', '20728', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22957', '22662', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20726'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20726'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '20728', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20726'}), items_add=frozenset({'22957', '22662', '20728', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '20726'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22662', '20728', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'22957', '22662', '22720', '22722', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20728'}), items_add=frozenset({'22957', '22662', '22720', '22722', '22383', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'22957', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20728'}), items_add=frozenset({'22957', '22662', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'22957', '22662', '22720', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'22662', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '22661'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '22662'}), items_add=frozenset({'22957', '20728', '22720', '2272 ...
# yes
# RelationRecord(items=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383', '22661', '20726'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383', '22661', '20726'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22957', '22662', '20719', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22957', '20728', '20719', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22662', '20728', '20719', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22957', '22662', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22722', '22383', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22662'}), items_add=frozenset({'22957', '20728', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22720'}), items_add=frozenset({'22957', '22662', '20728', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22957', '22662', '20728', '22720', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20719', '22957'}), items_add=frozenset({'22662', '20728', '22720', '22722', '22383', '22661', '20726'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'20728', '20726'}), items_add=frozenset({'22957', '22662', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22383', '20726'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22661', '20726'}), items_add=frozenset({'22957', '22662', '20728', '20719', '22720', '22722', '22383'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '20728', '20719', '22720', '22722', '22383', '22661'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22720', '20726'}), items_add ...

# %%
# frequentItemset65 = list(apriori(transactions65, min_support=0.5))

# for record in frequentItemset65:
#     if len(record.items) > 1:
#         print('yes')
#         print(f"Items: {', '.join(record.items)}")
#         print(f"Support: {record.support:.4f} ({record.support*100:.2f}%)")

#         for i, stat in enumerate(record.ordered_statistics, 1):
#             items_base = 'None' if not stat.items_base else ', '.join(stat.items_base)
#             items_add = ', '.join(stat.items_add)
#             confidence = stat.confidence
#             lift = stat.lift

#             print(f"Rule {i}: ({items_base} -> {items_add} : Confidence={confidence:.4f}, Lift={lift:.4f})")
#         print()
